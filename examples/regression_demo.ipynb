# %% [markdown]
# # GALAX Regression Demo
#
# This notebook demonstrates how to use GALAX for spatial regression analysis with Buffalo 311 call request data.
#
# ## Contents
# 1. Data Loading and Preprocessing
# 2. Model Configuration
# 3. Model Fitting
# 4. Results Visualization

# %%
import sys
sys.path.append('../')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from sklearn.preprocessing import StandardScaler
from galax.GALAX import GALAX
from joblib import load

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# %% [markdown]
# ## 1. Data Loading and Preprocessing

# %%
data = pd.read_csv("../data/311Request.csv")

print(f"Dataset shape: {data.shape}")
print(f"\nFirst few rows:")
data.head()
# Out:
# Dataset shape: (290, 22)
#
# First few rows:
#          GEO_ID  snow depth  % below poverty  % civilian unemployed  \
# 0  360290002004  280.143000         0.107573               0.029508
# 1  360290167003  264.945327         0.489362               0.076739
# 2  360290019001  271.640163         0.122899               0.000000
# 3  360290037003  195.429000         0.450739               0.116402
# 4  360290041004  181.923775         0.112536               0.039630
#
#    % capita income  % no high school  % 65 older  % 17 younger  \
# 0            23291          0.217949    0.100688      0.261618
# 1            21240          0.261029    0.194849      0.217245
# 2            33697          0.168750    0.205882      0.089286
# 3            17241          0.180851    0.133005      0.285714
# 4            32434          0.180470    0.150997      0.185185
#
#    % household disability  % single parent household  ...  % multi unit  \
# 0                0.340426                   0.605263  ...      0.000000
# 1                0.259336                   1.000000  ...      0.036232
# 2                0.282692                   0.000000  ...      0.000000
# 3                0.570588                   0.181034  ...      0.000000
# 4                0.370301                   0.219895  ...      0.000000
#
#    % mobile homes  % crowding  % no vehicle  % group quarters  \
# 0        0.090726    0.000000      0.229787               0.0
# 1        0.000000    0.000000      0.176349               0.0
# 2        0.000000    0.000000      0.115385               0.0
# 3        0.000000    0.000000      0.094118               0.0
# 4        0.026277    0.071429      0.133459               0.0
#
#    historical requests  neighbor historical request     Lon     Lat  \
# 0             1.563683                     0.514790  329858  316951
# 1             0.315789                     0.230171  331577  319732
# 2             0.269958                     0.226554  331272  318564
# 3             0.379310                     0.232020  331441  324382
# 4             0.148148                     0.115461  332122  324962
#
#    311_requests
# 0    206.540447
# 1     71.668533
# 2     68.277311
# 3    142.857143
# 4     44.159544
#
# [5 rows x 22 columns]

# %%
# Prepare features and target
columns_to_exclude = ['CBG ID', 'Lon', 'Lat', '311_requests']
x_vars = [column for column in data.columns if column not in columns_to_exclude]

print(f"Feature variables ({len(x_vars)}): {x_vars}")

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(data[x_vars])
y = data['311_requests'].values.reshape(-1, 1)
coords = data[['Lon', 'Lat']].values

print(f"\nTarget variable statistics:")
print(f"  Mean: {y.mean():.2f}")
print(f"  Std: {y.std():.2f}")
print(f"  Min: {y.min():.2f}")
print(f"  Max: {y.max():.2f}")
# Out:
# Feature variables (19): ['GEO_ID', 'snow depth', '% below poverty', '% civilian unemployed', '% capita income', '% no high school', '% 65 older', '% 17 younger', '% household disability', '% single parent household', '% minority', '% not well english', '% multi unit', '% mobile homes', '% crowding', '% no vehicle', '% group quarters', 'historical requests', 'neighbor historical request']
#
# Target variable statistics:
#   Mean: 24.00
#   Std: 20.34
#   Min: 0.00
#   Max: 206.54

# %% [markdown]
# ## 2. Model Configuration

# %%
automl_settings = {
    "time_budget": 180,  # Time budget in seconds
    "estimator_list": ['rf', 'xgboost', 'xgb_limitdepth', 'extra_tree'],
    "task": 'regression',
    "metric": 'r2',
    "seed": 42,
    "verbose": 0,
}

# %% [markdown]
# ## 3. Model Fitting
#
# GALAX will automatically select the optimal bandwidth using Incremental Spatial Autocorrelation (ISA) and fit local models at each location.

# %%
model = GALAX(
    coords=coords,
    y=y,
    X=X,
    bw='isa',
    kernel='bisquare',
    automl_settings=automl_settings,
    task='regression',
    n_jobs=16,
    x_vars=x_vars
)

results = model.fit()
# Out:
# Starting ISA bandwidth selection...
#
# Starting bandwidth search:
# - Minimum bandwidth: 21
# - Maximum bandwidth: 276
# - Step size: 1
# --------------------------------------------------
#
# Testing bandwidth 21 (1/256)...
#
# Testing bandwidth 22 (2/256)...
#
# Testing bandwidth 23 (3/256)...
#
# Testing bandwidth 24 (4/256)...
#
# Testing bandwidth 25 (5/256)...
#
# Testing bandwidth 26 (6/256)...
#
# Testing bandwidth 27 (7/256)...
#
# Testing bandwidth 28 (8/256)...
#
# Testing bandwidth 29 (9/256)...
#
# Testing bandwidth 30 (10/256)...
#
# Testing bandwidth 31 (11/256)...
#
# Testing bandwidth 32 (12/256)...
#
# Testing bandwidth 33 (13/256)...
#
# Testing bandwidth 34 (14/256)...
#
# Testing bandwidth 35 (15/256)...
#
# Testing bandwidth 36 (16/256)...
#
# Testing bandwidth 37 (17/256)...
#
# Testing bandwidth 38 (18/256)...
#
# Testing bandwidth 39 (19/256)...
#
# Testing bandwidth 40 (20/256)...
#
# Testing bandwidth 41 (21/256)...
#
# Testing bandwidth 42 (22/256)...
#
# Testing bandwidth 43 (23/256)...
#
# Testing bandwidth 44 (24/256)...
#
# Testing bandwidth 45 (25/256)...
#
# Testing bandwidth 46 (26/256)...
#
# Testing bandwidth 47 (27/256)...
#
# Testing bandwidth 48 (28/256)...
#
# Testing bandwidth 49 (29/256)...
#
# Testing bandwidth 50 (30/256)...
#
# Testing bandwidth 51 (31/256)...
#
# Testing bandwidth 52 (32/256)...
#
# Testing bandwidth 53 (33/256)...
#
# Testing bandwidth 54 (34/256)...
#
# Testing bandwidth 55 (35/256)...
#
# Testing bandwidth 56 (36/256)...
#
# Testing bandwidth 57 (37/256)...
#
# Testing bandwidth 58 (38/256)...
#
# Testing bandwidth 59 (39/256)...
#
# Testing bandwidth 60 (40/256)...
#
# Testing bandwidth 61 (41/256)...
#
# Testing bandwidth 62 (42/256)...
#
# Testing bandwidth 63 (43/256)...
#
# Testing bandwidth 64 (44/256)...
#
# Testing bandwidth 65 (45/256)...
#
# Testing bandwidth 66 (46/256)...
#
# Testing bandwidth 67 (47/256)...
#
# Testing bandwidth 68 (48/256)...
#
# Testing bandwidth 69 (49/256)...
#
# Testing bandwidth 70 (50/256)...
#
# Testing bandwidth 71 (51/256)...
#
# Testing bandwidth 72 (52/256)...
#
# Testing bandwidth 73 (53/256)...
#
# Testing bandwidth 74 (54/256)...
#
# Testing bandwidth 75 (55/256)...
#
# Testing bandwidth 76 (56/256)...
#
# Testing bandwidth 77 (57/256)...
#
# Testing bandwidth 78 (58/256)...
#
# Testing bandwidth 79 (59/256)...
#
# Testing bandwidth 80 (60/256)...
#
# Testing bandwidth 81 (61/256)...
#
# Testing bandwidth 82 (62/256)...
#
# Testing bandwidth 83 (63/256)...
#
# Testing bandwidth 84 (64/256)...
#
# Testing bandwidth 85 (65/256)...
#
# Testing bandwidth 86 (66/256)...
#
# Testing bandwidth 87 (67/256)...
#
# Testing bandwidth 88 (68/256)...
#
# Testing bandwidth 89 (69/256)...
#
# Testing bandwidth 90 (70/256)...
#
# Testing bandwidth 91 (71/256)...
#
# Testing bandwidth 92 (72/256)...
#
# Testing bandwidth 93 (73/256)...
#
# Testing bandwidth 94 (74/256)...
#
# Testing bandwidth 95 (75/256)...
#
# Testing bandwidth 96 (76/256)...
#
# Testing bandwidth 97 (77/256)...
#
# Testing bandwidth 98 (78/256)...
#
# Testing bandwidth 99 (79/256)...
#
# Testing bandwidth 100 (80/256)...
#
# Testing bandwidth 101 (81/256)...
#
# Testing bandwidth 102 (82/256)...
#
# Testing bandwidth 103 (83/256)...
#
# Testing bandwidth 104 (84/256)...
#
# Testing bandwidth 105 (85/256)...
#
# Testing bandwidth 106 (86/256)...
#
# Testing bandwidth 107 (87/256)...
#
# Testing bandwidth 108 (88/256)...
#
# Testing bandwidth 109 (89/256)...
#
# Testing bandwidth 110 (90/256)...
#
# Testing bandwidth 111 (91/256)...
#
# Testing bandwidth 112 (92/256)...
#
# Testing bandwidth 113 (93/256)...
#
# Testing bandwidth 114 (94/256)...
#
# Testing bandwidth 115 (95/256)...
#
# Testing bandwidth 116 (96/256)...
#
# Testing bandwidth 117 (97/256)...
#
# Testing bandwidth 118 (98/256)...
#
# Testing bandwidth 119 (99/256)...
#
# Testing bandwidth 120 (100/256)...
#
# Testing bandwidth 121 (101/256)...
#
# Testing bandwidth 122 (102/256)...
#
# Testing bandwidth 123 (103/256)...
#
# Testing bandwidth 124 (104/256)...
#
# Testing bandwidth 125 (105/256)...
#
# Testing bandwidth 126 (106/256)...
#
# Testing bandwidth 127 (107/256)...
#
# Testing bandwidth 128 (108/256)...
#
# Testing bandwidth 129 (109/256)...
#
# Testing bandwidth 130 (110/256)...
#
# Testing bandwidth 131 (111/256)...
#
# Testing bandwidth 132 (112/256)...
#
# Testing bandwidth 133 (113/256)...
#
# Testing bandwidth 134 (114/256)...
#
# Testing bandwidth 135 (115/256)...
#
# Testing bandwidth 136 (116/256)...
#
# Testing bandwidth 137 (117/256)...
#
# Testing bandwidth 138 (118/256)...
#
# Testing bandwidth 139 (119/256)...
#
# Testing bandwidth 140 (120/256)...
#
# Testing bandwidth 141 (121/256)...
#
# Testing bandwidth 142 (122/256)...
#
# Testing bandwidth 143 (123/256)...
#
# Testing bandwidth 144 (124/256)...
#
# Testing bandwidth 145 (125/256)...
#
# Testing bandwidth 146 (126/256)...
#
# Testing bandwidth 147 (127/256)...
#
# Testing bandwidth 148 (128/256)...
#
# Testing bandwidth 149 (129/256)...
#
# Testing bandwidth 150 (130/256)...
#
# Testing bandwidth 151 (131/256)...
#
# Testing bandwidth 152 (132/256)...
#
# Testing bandwidth 153 (133/256)...
#
# Testing bandwidth 154 (134/256)...
#
# Testing bandwidth 155 (135/256)...
#
# Testing bandwidth 156 (136/256)...
#
# Testing bandwidth 157 (137/256)...
#
# Testing bandwidth 158 (138/256)...
#
# Testing bandwidth 159 (139/256)...
#
# Testing bandwidth 160 (140/256)...
#
# Testing bandwidth 161 (141/256)...
#
# Testing bandwidth 162 (142/256)...
#
# Testing bandwidth 163 (143/256)...
#
# Testing bandwidth 164 (144/256)...
#
# Testing bandwidth 165 (145/256)...
#
# Testing bandwidth 166 (146/256)...
#
# Testing bandwidth 167 (147/256)...
#
# Testing bandwidth 168 (148/256)...
#
# Testing bandwidth 169 (149/256)...
#
# Testing bandwidth 170 (150/256)...
#
# Testing bandwidth 171 (151/256)...
#
# Testing bandwidth 172 (152/256)...
#
# Testing bandwidth 173 (153/256)...
#
# Testing bandwidth 174 (154/256)...
#
# Testing bandwidth 175 (155/256)...
#
# Testing bandwidth 176 (156/256)...
#
# Testing bandwidth 177 (157/256)...
#
# Testing bandwidth 178 (158/256)...
#
# Testing bandwidth 179 (159/256)...
#
# Testing bandwidth 180 (160/256)...
#
# Testing bandwidth 181 (161/256)...
#
# Testing bandwidth 182 (162/256)...
#
# Testing bandwidth 183 (163/256)...
#
# Testing bandwidth 184 (164/256)...
#
# Testing bandwidth 185 (165/256)...
#
# Testing bandwidth 186 (166/256)...
#
# Testing bandwidth 187 (167/256)...
#
# Testing bandwidth 188 (168/256)...
#
# Testing bandwidth 189 (169/256)...
#
# Testing bandwidth 190 (170/256)...
#
# Testing bandwidth 191 (171/256)...
#
# Testing bandwidth 192 (172/256)...
#
# Testing bandwidth 193 (173/256)...
#
# Testing bandwidth 194 (174/256)...
#
# Testing bandwidth 195 (175/256)...
#
# Testing bandwidth 196 (176/256)...
#
# Testing bandwidth 197 (177/256)...
#
# Testing bandwidth 198 (178/256)...
#
# Testing bandwidth 199 (179/256)...
#
# Testing bandwidth 200 (180/256)...
#
# Testing bandwidth 201 (181/256)...
#
# Testing bandwidth 202 (182/256)...
#
# Testing bandwidth 203 (183/256)...
#
# Testing bandwidth 204 (184/256)...
#
# Testing bandwidth 205 (185/256)...
#
# Testing bandwidth 206 (186/256)...
#
# Testing bandwidth 207 (187/256)...
#
# Testing bandwidth 208 (188/256)...
#
# Testing bandwidth 209 (189/256)...
#
# Testing bandwidth 210 (190/256)...
#
# Testing bandwidth 211 (191/256)...
#
# Testing bandwidth 212 (192/256)...
#
# Testing bandwidth 213 (193/256)...
#
# Testing bandwidth 214 (194/256)...
#
# Testing bandwidth 215 (195/256)...
#
# Testing bandwidth 216 (196/256)...
#
# Testing bandwidth 217 (197/256)...
#
# Testing bandwidth 218 (198/256)...
#
# Testing bandwidth 219 (199/256)...
#
# Testing bandwidth 220 (200/256)...
#
# Testing bandwidth 221 (201/256)...
#
# Testing bandwidth 222 (202/256)...
#
# Testing bandwidth 223 (203/256)...
#
# Testing bandwidth 224 (204/256)...
#
# Testing bandwidth 225 (205/256)...
#
# Testing bandwidth 226 (206/256)...
#
# Testing bandwidth 227 (207/256)...
#
# Testing bandwidth 228 (208/256)...
#
# Testing bandwidth 229 (209/256)...
#
# Testing bandwidth 230 (210/256)...
#
# Testing bandwidth 231 (211/256)...
#
# Testing bandwidth 232 (212/256)...
#
# Testing bandwidth 233 (213/256)...
#
# Testing bandwidth 234 (214/256)...
#
# Testing bandwidth 235 (215/256)...
#
# Testing bandwidth 236 (216/256)...
#
# Testing bandwidth 237 (217/256)...
#
# Testing bandwidth 238 (218/256)...
#
# Testing bandwidth 239 (219/256)...
#
# Testing bandwidth 240 (220/256)...
#
# Testing bandwidth 241 (221/256)...
#
# Testing bandwidth 242 (222/256)...
#
# Testing bandwidth 243 (223/256)...
#
# Testing bandwidth 244 (224/256)...
#
# Testing bandwidth 245 (225/256)...
#
# Testing bandwidth 246 (226/256)...
#
# Testing bandwidth 247 (227/256)...
#
# Testing bandwidth 248 (228/256)...
#
# Testing bandwidth 249 (229/256)...
#
# Testing bandwidth 250 (230/256)...
#
# Testing bandwidth 251 (231/256)...
#
# Testing bandwidth 252 (232/256)...
#
# Testing bandwidth 253 (233/256)...
#
# Testing bandwidth 254 (234/256)...
#
# Testing bandwidth 255 (235/256)...
#
# Testing bandwidth 256 (236/256)...
#
# Testing bandwidth 257 (237/256)...
#
# Testing bandwidth 258 (238/256)...
#
# Testing bandwidth 259 (239/256)...
#
# Testing bandwidth 260 (240/256)...
#
# Testing bandwidth 261 (241/256)...
#
# Testing bandwidth 262 (242/256)...
#
# Testing bandwidth 263 (243/256)...
#
# Testing bandwidth 264 (244/256)...
#
# Testing bandwidth 265 (245/256)...
#
# Testing bandwidth 266 (246/256)...
#
# Testing bandwidth 267 (247/256)...
#
# Testing bandwidth 268 (248/256)...
#
# Testing bandwidth 269 (249/256)...
#
# Testing bandwidth 270 (250/256)...
#
# Testing bandwidth 271 (251/256)...
#
# Testing bandwidth 272 (252/256)...
#
# Testing bandwidth 273 (253/256)...
#
# Testing bandwidth 274 (254/256)...
#
# Testing bandwidth 275 (255/256)...
#
# Testing bandwidth 276 (256/256)...
#
# Bandwidth search completed:
# - Tested 256 bandwidths
# - 0 bandwidths accepted
# - 256 bandwidths rejected
#
# Optimal bandwidth found: 135
# Moran's I: 0.0704
# p-value: 0.0000
# ISA bandwidth selection successful:
# - Optimal bandwidth: 135
# - Moran's I: 0.0704
# - p-value: 0.0000
# Location 8/290 successfully trained ML model
# Location 2/290 successfully trained ML model
# Location 14/290 successfully trained ML model
# Location 5/290 successfully trained ML model
# Location 9/290 successfully trained ML model
# Location 7/290 successfully trained ML model
# Location 0/290 successfully trained ML model
# Location 4/290 successfully trained ML model
# Location 11/290 successfully trained ML model
# Location 6/290 successfully trained ML model
# Location 1/290 successfully trained ML model
# Location 15/290 successfully trained ML model
# Location 13/290 successfully trained ML model
# Location 3/290 successfully trained ML model
# Location 10/290 successfully trained ML model
# Location 12/290 successfully trained ML model
# Location 16/290 successfully trained ML model
# Location 19/290 successfully trained ML model
# Location 17/290 successfully trained ML model
# Location 18/290 successfully trained ML model
# Location 26/290 successfully trained ML model
# Location 20/290 successfully trained ML model
# Location 24/290 successfully trained ML model
# Location 22/290 successfully trained ML model
# Location 31/290 successfully trained ML model
# Location 27/290 successfully trained ML model
# Location 28/290 successfully trained ML model
# Location 21/290 successfully trained ML model
# Location 30/290 successfully trained ML model
# Location 25/290 successfully trained ML model
# Location 29/290 successfully trained ML model
# Location 23/290 successfully trained ML model
# Location 34/290 successfully trained ML model
# Location 32/290 successfully trained ML model
# Location 36/290 successfully trained ML model
# Location 39/290 successfully trained ML model
# Location 38/290 successfully trained ML model
# Location 35/290 successfully trained ML model
# Location 37/290 successfully trained ML model
# Location 33/290 successfully trained ML model
# Location 42/290 successfully trained ML model
# Location 41/290 successfully trained ML model
# Location 44/290 successfully trained ML model
# Location 40/290 successfully trained ML model
# Location 46/290 successfully trained ML model
# Location 45/290 successfully trained ML model
# Location 47/290 successfully trained ML model
# Location 43/290 successfully trained ML model
# Location 55/290 successfully trained ML model
# Location 56/290 successfully trained ML model
# Location 51/290 successfully trained ML model
# Location 49/290 successfully trained ML model
# Location 58/290 successfully trained ML model
# Location 52/290 successfully trained ML model
# Location 61/290 successfully trained ML model
# Location 48/290 successfully trained ML model
# Location 57/290 successfully trained ML model
# Location 59/290 successfully trained ML model
# Location 60/290 successfully trained ML model
# Location 53/290 successfully trained ML model
# Location 50/290 successfully trained ML model
# Location 54/290 successfully trained ML model
# Location 62/290 successfully trained ML model
# Location 63/290 successfully trained ML model
# Location 71/290 successfully trained ML model
# Location 70/290 successfully trained ML model
# Location 74/290 successfully trained ML model
# Location 77/290 successfully trained ML model
# Location 68/290 successfully trained ML model
# Location 64/290 successfully trained ML model
# Location 67/290 successfully trained ML model
# Location 76/290 successfully trained ML model
# Location 72/290 successfully trained ML model
# Location 75/290 successfully trained ML model
# Location 73/290 successfully trained ML model
# Location 69/290 successfully trained ML model
# Location 66/290 successfully trained ML model
# Location 65/290 successfully trained ML model
# Location 78/290 successfully trained ML model
# Location 79/290 successfully trained ML model
# Location 86/290 successfully trained ML model
# Location 85/290 successfully trained ML model
# Location 82/290 successfully trained ML model
# Location 90/290 successfully trained ML model
# Location 83/290 successfully trained ML model
# Location 80/290 successfully trained ML model
# Location 87/290 successfully trained ML model
# Location 91/290 successfully trained ML model
# Location 93/290 successfully trained ML model
# Location 89/290 successfully trained ML model
# Location 92/290 successfully trained ML model
# Location 84/290 successfully trained ML model
# Location 94/290 successfully trained ML model
# Location 88/290 successfully trained ML model
# Location 81/290 successfully trained ML model
# Location 95/290 successfully trained ML model
# Location 97/290 successfully trained ML model
# Location 104/290 successfully trained ML model
# Location 103/290 successfully trained ML model
# Location 105/290 successfully trained ML model
# Location 101/290 successfully trained ML model
# Location 98/290 successfully trained ML model
# Location 102/290 successfully trained ML model
# Location 99/290 successfully trained ML model
# Location 106/290 successfully trained ML model
# Location 107/290 successfully trained ML model
# Location 109/290 successfully trained ML model
# Location 96/290 successfully trained ML model
# Location 108/290 successfully trained ML model
# Location 100/290 successfully trained ML model
# Location 110/290 successfully trained ML model
# Location 111/290 successfully trained ML model
# Location 114/290 successfully trained ML model
# Location 112/290 successfully trained ML model
# Location 116/290 successfully trained ML model
# Location 115/290 successfully trained ML model
# Location 113/290 successfully trained ML model
# Location 121/290 successfully trained ML model
# Location 119/290 successfully trained ML model
# Location 118/290 successfully trained ML model
# Location 122/290 successfully trained ML model
# Location 117/290 successfully trained ML model
# Location 125/290 successfully trained ML model
# Location 123/290 successfully trained ML model
# Location 126/290 successfully trained ML model
# Location 124/290 successfully trained ML model
# Location 120/290 successfully trained ML model
# Location 127/290 successfully trained ML model
# Location 131/290 successfully trained ML model
# Location 132/290 successfully trained ML model
# Location 130/290 successfully trained ML model
# Location 129/290 successfully trained ML model
# Location 133/290 successfully trained ML model
# Location 128/290 successfully trained ML model
# Location 136/290 successfully trained ML model
# Location 134/290 successfully trained ML model
# Location 135/290 successfully trained ML model
# Location 137/290 successfully trained ML model
# Location 138/290 successfully trained ML model
# Location 139/290 successfully trained ML model
# Location 140/290 successfully trained ML model
# Location 141/290 successfully trained ML model
# Location 142/290 successfully trained ML model
# Location 143/290 successfully trained ML model
# Location 147/290 successfully trained ML model
# Location 144/290 successfully trained ML model
# Location 149/290 successfully trained ML model
# Location 146/290 successfully trained ML model
# Location 148/290 successfully trained ML model
# Location 150/290 successfully trained ML model
# Location 151/290 successfully trained ML model
# Location 145/290 successfully trained ML model
# Location 152/290 successfully trained ML model
# Location 157/290 successfully trained ML model
# Location 153/290 successfully trained ML model
# Location 154/290 successfully trained ML model
# Location 156/290 successfully trained ML model
# Location 158/290 successfully trained ML model
# Location 155/290 successfully trained ML model
# Location 159/290 successfully trained ML model
# Location 161/290 successfully trained ML model
# Location 162/290 successfully trained ML model
# Location 163/290 successfully trained ML model
# Location 166/290 successfully trained ML model
# Location 165/290 successfully trained ML model
# Location 164/290 successfully trained ML model
# Location 160/290 successfully trained ML model
# Location 169/290 successfully trained ML model
# Location 168/290 successfully trained ML model
# Location 171/290 successfully trained ML model
# Location 167/290 successfully trained ML model
# Location 173/290 successfully trained ML model
# Location 172/290 successfully trained ML model
# Location 174/290 successfully trained ML model
# Location 170/290 successfully trained ML model
# Location 175/290 successfully trained ML model
# Location 176/290 successfully trained ML model
# Location 178/290 successfully trained ML model
# Location 179/290 successfully trained ML model
# Location 181/290 successfully trained ML model
# Location 183/290 successfully trained ML model
# Location 180/290 successfully trained ML model
# Location 182/290 successfully trained ML model
# Location 184/290 successfully trained ML model
# Location 185/290 successfully trained ML model
# Location 186/290 successfully trained ML model
# Location 189/290 successfully trained ML model
# Location 187/290 successfully trained ML model
# Location 177/290 successfully trained ML model
# Location 190/290 successfully trained ML model
# Location 188/290 successfully trained ML model
# Location 191/290 successfully trained ML model
# Location 193/290 successfully trained ML model
# Location 198/290 successfully trained ML model
# Location 195/290 successfully trained ML model
# Location 196/290 successfully trained ML model
# Location 200/290 successfully trained ML model
# Location 201/290 successfully trained ML model
# Location 202/290 successfully trained ML model
# Location 199/290 successfully trained ML model
# Location 203/290 successfully trained ML model
# Location 194/290 successfully trained ML model
# Location 205/290 successfully trained ML model
# Location 197/290 successfully trained ML model
# Location 204/290 successfully trained ML model
# Location 192/290 successfully trained ML model
# Location 206/290 successfully trained ML model
# Location 207/290 successfully trained ML model
# Location 211/290 successfully trained ML model
# Location 212/290 successfully trained ML model
# Location 209/290 successfully trained ML model
# Location 213/290 successfully trained ML model
# Location 214/290 successfully trained ML model
# Location 215/290 successfully trained ML model
# Location 210/290 successfully trained ML model
# Location 217/290 successfully trained ML model
# Location 216/290 successfully trained ML model
# Location 218/290 successfully trained ML model
# Location 220/290 successfully trained ML model
# Location 221/290 successfully trained ML model
# Location 219/290 successfully trained ML model
# Location 208/290 successfully trained ML model
# Location 222/290 successfully trained ML model
# Location 223/290 successfully trained ML model
# Location 226/290 successfully trained ML model
# Location 229/290 successfully trained ML model
# Location 228/290 successfully trained ML model
# Location 230/290 successfully trained ML model
# Location 231/290 successfully trained ML model
# Location 225/290 successfully trained ML model
# Location 224/290 successfully trained ML model
# Location 232/290 successfully trained ML model
# Location 236/290 successfully trained ML model
# Location 234/290 successfully trained ML model
# Location 227/290 successfully trained ML model
# Location 233/290 successfully trained ML model
# Location 235/290 successfully trained ML model
# Location 237/290 successfully trained ML model
# Location 239/290 successfully trained ML model
# Location 238/290 successfully trained ML model
# Location 244/290 successfully trained ML model
# Location 243/290 successfully trained ML model
# Location 249/290 successfully trained ML model
# Location 240/290 successfully trained ML model
# Location 247/290 successfully trained ML model
# Location 245/290 successfully trained ML model
# Location 252/290 successfully trained ML model
# Location 250/290 successfully trained ML model
# Location 246/290 successfully trained ML model
# Location 242/290 successfully trained ML model
# Location 248/290 successfully trained ML model
# Location 251/290 successfully trained ML model
# Location 241/290 successfully trained ML model
# Location 253/290 successfully trained ML model
# Location 254/290 successfully trained ML model
# Location 255/290 successfully trained ML model
# Location 256/290 successfully trained ML model
# Location 260/290 successfully trained ML model
# Location 267/290 successfully trained ML model
# Location 263/290 successfully trained ML model
# Location 268/290 successfully trained ML model
# Location 257/290 successfully trained ML model
# Location 259/290 successfully trained ML model
# Location 269/290 successfully trained ML model
# Location 261/290 successfully trained ML model
# Location 264/290 successfully trained ML model
# Location 265/290 successfully trained ML model
# Location 262/290 successfully trained ML model
# Location 266/290 successfully trained ML model
# Location 270/290 successfully trained ML model
# Location 258/290 successfully trained ML model
# Location 271/290 successfully trained ML model
# Location 272/290 successfully trained ML model
# Location 274/290 successfully trained ML model
# Location 275/290 successfully trained ML model
# Location 277/290 successfully trained ML model
# Location 276/290 successfully trained ML model
# Location 273/290 successfully trained ML model
# Location 279/290 successfully trained ML model
# Location 280/290 successfully trained ML model
# Location 282/290 successfully trained ML model
# Location 281/290 successfully trained ML model
# Location 278/290 successfully trained ML model
# Location 284/290 successfully trained ML model
# Location 283/290 successfully trained ML model
# Location 285/290 successfully trained ML model
# Location 287/290 successfully trained ML model
# Location 286/290 successfully trained ML model
# Location 288/290 successfully trained ML model
# Location 289/290 successfully trained ML model
# Total Successfully processed location: 290 / 290

# %% [markdown]
# ## 4. Results Summary and Visualization

# %%
results.summary()
# Out:
# GALAX Results Summary
# --------------------------------------------------
# Task: regression
# Bandwidth: 135
# Global R²: 0.9252
# Global RMSE: 5.5644
# Local R² Statistics:
#   - Mean: 0.8490
#   - Min: 0.3227
#   - Max: 0.9998
#   - Std: 0.1222
# Local RMSE Statistics:
#   - Mean: 6.5236
#   - Min: 0.1644
#   - Max: 22.9858
#   - Std: 4.0701

# %% [markdown]
# ### Save Results

# %%
results.save_results('../results/GALAX_regression_results.joblib')
print("Results saved to ../results/GALAX_regression_results.joblib")
# Out:
# Results saved to ../results/GALAX_regression_results.joblib

# %% [markdown]
# ### Spatial Distribution of Local R² Values

# %%
buffalo_cbgs = gpd.read_file('../data/buffalo/buffalo.shp')

# Create a DataFrame with GEO_ID and Local R² values
local_r2_data = pd.DataFrame({
    'GEO_ID': data['GEO_ID'].astype(str),
    'Local_R2': results.local_metrics
})

# Merge CBG geometries with Local R² data
buffalo_cbgs['GEOID'] = buffalo_cbgs['GEOID'].astype(str)
merged_cbgs = buffalo_cbgs.merge(local_r2_data, left_on='GEOID', right_on='GEO_ID')

fig, ax = plt.subplots(figsize=(12, 8))

merged_cbgs.plot(column='Local_R2', 
                 cmap='RdYlGn', 
                 ax=ax,
                 edgecolor='black', 
                 linewidth=0.5,
                 vmin=0, 
                 vmax=1,
                 legend=True,
                 legend_kwds={'label': 'Local R²', 'shrink': 0.8})

ax.set_xlabel('Longitude', fontsize=12)
ax.set_ylabel('Latitude', fontsize=12)
ax.set_title('Spatial Distribution of Local R² Values', fontsize=14, fontweight='bold')
plt.tight_layout()
fig.savefig('../results/regression_r2.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Spatial Variation in Feature Importance
#
# Visualize how feature importance varies across space for the most important feature.

# %%
saved_results = load('../results/GALAX_regression_results.joblib')

# Extract SHAP values
mean_abs_shap = []
for loc_result in saved_results['location_results']:
    if 'raw_shap_values_neighbors' in loc_result and loc_result['raw_shap_values_neighbors'] is not None:
        shap_values = np.array(loc_result['raw_shap_values_neighbors'])
        if shap_values.ndim == 2:
            mean_abs_shap.append(np.mean(np.abs(shap_values), axis=0))

mean_abs_shap = np.array(mean_abs_shap)
global_importance = np.mean(mean_abs_shap, axis=0)
feature_names = x_vars if x_vars else [f'Feature {i}' for i in range(len(global_importance))]
sorted_idx = np.argsort(global_importance)[::-1][:10]

most_important_feature_idx = sorted_idx[0]
most_important_feature = feature_names[most_important_feature_idx]

# Extract mean absolute SHAP for this feature at each location
feature_shap_by_location = mean_abs_shap[:, most_important_feature_idx]

# Create a DataFrame with GEO_ID and feature importance values
feature_importance_data = pd.DataFrame({
    'GEO_ID': data['GEO_ID'].astype(str),
    'Feature_Importance': feature_shap_by_location
})

# Merge CBG geometries with feature importance data
buffalo_cbgs['GEOID'] = buffalo_cbgs['GEOID'].astype(str)
merged_cbgs_feature = buffalo_cbgs.merge(feature_importance_data, left_on='GEOID', right_on='GEO_ID')

fig, ax = plt.subplots(figsize=(12, 8))

merged_cbgs_feature.plot(column='Feature_Importance', 
                         cmap='viridis', 
                         ax=ax,
                         edgecolor='black', 
                         linewidth=0.5,
                         legend=True,
                         legend_kwds={'label': f'Mean |SHAP| for {most_important_feature}', 'shrink': 0.8})

ax.set_xlabel('Longitude', fontsize=12)
ax.set_ylabel('Latitude', fontsize=12)
ax.set_title(f'Spatial Variation in Importance of {most_important_feature}', fontsize=14, fontweight='bold')
plt.tight_layout()
fig.savefig('../results/regression_feature.png', dpi=300, bbox_inches='tight')
plt.show()
